# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ced1fe9-a5a9-45d3-b1c2-57d5e8fa6e42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ced1fe9-a5a9-45d3-b1c2-57d5e8fa6e42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urlset - urlset.csv to urlset - urlset.csv

# %%
data=pd.read_csv('urlset - urlset.csv')

# %%
data.head()
# Out:
#                                               domain  ...  Unnamed: 14
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...  ...          NaN
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...  ...          NaN
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....  ...          NaN
# 3  mail.printakid.com/www.online.americanexpress....  ...          NaN
# 4  thewhiskeydregs.com/wp-content/themes/widescre...  ...          NaN
#
# [5 rows x 15 columns]

# %%
data.drop(['ranking','mld_res','mld.ps_res','card_rem','ratio_Rrem','ratio_Arem','jaccard_RR','jaccard_RA','jaccard_AR','jaccard_AA','jaccard_ARrd','jaccard_ARrem'],axis='columns',inplace=True)

# %%
data.head()
# Out:
#                                               domain  label  Unnamed: 14
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...    1.0          NaN
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...    1.0          NaN
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....    1.0          NaN
# 3  mail.printakid.com/www.online.americanexpress....    1.0          NaN
# 4  thewhiskeydregs.com/wp-content/themes/widescre...    1.0          NaN

# %%
data.dropna()
# Out:
# Empty DataFrame
# Columns: [domain, label, Unnamed: 14]
# Index: []

# %%
data.head()
# Out:
#                                               domain  label  Unnamed: 14
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...    1.0          NaN
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...    1.0          NaN
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....    1.0          NaN
# 3  mail.printakid.com/www.online.americanexpress....    1.0          NaN
# 4  thewhiskeydregs.com/wp-content/themes/widescre...    1.0          NaN

# %%
data.drop(data[data['label'] == 0].index, inplace = True)

# %%
data.describe()
# Out:
#          label  Unnamed: 14
# count  47902.0          2.0
# mean       1.0          1.0
# std        0.0          0.0
# min        1.0          1.0
# 25%        1.0          1.0
# 50%        1.0          1.0
# 75%        1.0          1.0
# max        1.0          1.0

# %%
data.head()
# Out:
#                                               domain  label  Unnamed: 14
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...    1.0          NaN
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...    1.0          NaN
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....    1.0          NaN
# 3  mail.printakid.com/www.online.americanexpress....    1.0          NaN
# 4  thewhiskeydregs.com/wp-content/themes/widescre...    1.0          NaN

# %%
def trim(string):
    string=str(string)
    v1=string.find('/')
    string=string[0:v1]
    return string

# %%
data.describe()
# Out:
#          label  Unnamed: 14
# count  47902.0          2.0
# mean       1.0          1.0
# std        0.0          0.0
# min        1.0          1.0
# 25%        1.0          1.0
# 50%        1.0          1.0
# 75%        1.0          1.0
# max        1.0          1.0

# %%
for i in range(0,47902):
  data.at[i,'domain']=trim(data.at[i,'domain'])

# %%
data.head()
# Out:
#                 domain  label  Unnamed: 14
# 0            nobell.it    1.0          NaN
# 1      www.dghjdgf.com    1.0          NaN
# 2     serviciosbys.com    1.0          NaN
# 3   mail.printakid.com    1.0          NaN
# 4  thewhiskeydregs.com    1.0          NaN

# %%
data.describe()
# Out:
#          label  Unnamed: 14
# count  47902.0          2.0
# mean       1.0          1.0
# std        0.0          0.0
# min        1.0          1.0
# 25%        1.0          1.0
# 50%        1.0          1.0
# 75%        1.0          1.0
# max        1.0          1.0

# %%
data.to_csv(r'E:\data\file.csv', index=False)
